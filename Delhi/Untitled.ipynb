# %%
import geopandas as gp

# %%
# ! cp data/GTFS/stops.txt ./stops.csv

# %%
X = gp.read_file("stops.csv")

# %%
X.head()
# Out:
#   stop_id stop_code                       stop_name   stop_lat   stop_lon  \
# 0       0    U01761  Adarsh Nagar / Bharola Village  28.715917  77.170867
# 1       1    DC4248          British High Comission  28.598533  77.191383
# 2       2    U02398                     Azad Market    28.6647    77.2084
# 3       3    U02416                    Kidwai Nagar    28.5757    77.2097
# 4       4    DC4271                   Rashid Market    28.6502  77.278667
#
#   geometry
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None

# %%
# type(X.stop_lon[0])
X.stop_lat = X.stop_lat.astype(float)
X.stop_lon = X.stop_lon.astype(float)

# %%
# X.plot()
y = gp.GeoDataFrame(X, geometry=gp.points_from_xy(X.stop_lon, X.stop_lat))

# %%
y.plot()

# %%
y.head()
# Out:
#   stop_id stop_code                       stop_name   stop_lat   stop_lon  \
# 0       0    U01761  Adarsh Nagar / Bharola Village  28.715917  77.170867
# 1       1    DC4248          British High Comission  28.598533  77.191383
# 2       2    U02398                     Azad Market  28.664700  77.208400
# 3       3    U02416                    Kidwai Nagar  28.575700  77.209700
# 4       4    DC4271                   Rashid Market  28.650200  77.278667
#
#                       geometry
# 0  POINT (77.170867 28.715917)
# 1  POINT (77.191383 28.598533)
# 2      POINT (77.2084 28.6647)
# 3      POINT (77.2097 28.5757)
# 4    POINT (77.278667 28.6502)

# %%
z = y.to_json()

# %%
z.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-657c699c9e26> in <module>()
# ----> 1 z.keys()
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
print (z)
# Out:
# {"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"stop_code": "U01761", "stop_id": "0", "stop_lat": 28.715917, "stop_lon": 77.170867, "stop_name": "Adarsh Nagar / Bharola Village"}, "geometry": {"type": "Point", "coordinates": [77.170867, 28.715917]}}, {"id": "1", "type": "Feature", "properties": {"stop_code": "DC4248", "stop_id": "1", "stop_lat": 28.598533, "stop_lon": 77.191383, "stop_name": "British High Comission"}, "geometry": {"type": "Point", "coordinates": [77.191383, 28.598533]}}, {"id": "2", "type": "Feature", "properties": {"stop_code": "U02398", "stop_id": "2", "stop_lat": 28.6647, "stop_lon": 77.2084, "stop_name": "Azad Market"}, "geometry": {"type": "Point", "coordinates": [77.2084, 28.6647]}}, {"id": "3", "type": "Feature", "properties": {"stop_code": "U02416", "stop_id": "3", "stop_lat": 28.5757, "stop_lon": 77.2097, "stop_name": "Kidwai Nagar"}, "geometry": {"type": "Point", "coordinates": [77.2097, 28.5757]}}, {"id": "4", "typ
# ...

# %%
zz = y.geometry
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-ca6b2bf101b5> in <module>()
# ----> 1 zz = y.geometry.exterior.xy[0]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# ~/anaconda2/lib/python3.6/site-packages/geopandas/base.py in exterior(self)
#     240         """
#     241         # TODO: return empty geometry for non-polygons
# --> 242         return _unary_geo('exterior', self)
#     243
#     244     @property
#
# ~/anaconda2/lib/python3.6/site-packages/geopandas/base.py in _unary_geo(op, this)
#      97     # ensure 1D output, see note above
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

mapbox_access_token = 'pk.eyJ1IjoiYWphaW4wMzk1IiwiYSI6ImNqeDczMWNkczAwcngzeHAzaDc2aGptaHIifQ.PrZuFAsV8w5ghhUhe8AF3w'

data = [
    go.Scattermapbox(
        lat=['38.91427','38.91538','38.91458',
             '38.92239','38.93222','38.90842',
             '38.91931','38.93260','38.91368',
             '38.88516','38.921894','38.93206',
             '38.91275'],
        lon=['-77.02827','-77.02013','-77.03155',
             '-77.04227','-77.02854','-77.02419',
             '-77.02518','-77.03304','-77.04509',
             '-76.99656','-77.042438','-77.02821',
             '-77.01239'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=9
        ),
        text=["The coffee bar","Bistro Bohem","Black Cat",
             "Snap","Columbia Heights Coffee","Azi's Cafe",
             "Blind Dog Cafe","Le Caprice","Filter",
             "Peregrine","Tryst","The Coupe",
             "Big Bear Cafe"],
    )
]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=go.layout.Mapbox(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=38.92,
            lon=-77.07
        ),
        pitch=0,
        zoom=10
    ),
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Multiple Mapbox')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~ajain0395/0 or inside your plot.ly account where it is named 'Multiple Mapbox'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ajain0395/0.embed" height="525px" width="100%"></iframe>

# %%
import plotly 
plotly.tools.set_credentials_file(username='ajain0395', api_key='CQXDIQrCVAhmxoqiR0C6')
