# %%
# from 
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

df = pd.read_csv(
    'https://gist.githubusercontent.com/chriddyp/' +
    '5d1ea79569ed194d432e56108a04d188/raw/' +
    'a9f9e8076b837d541398e999dcbac2b2826a81f8/'+
    'gdp-life-exp-2007.csv')
xd = pd.read_csv("./Delhi/sunday.csv")

app.layout = html.Div([
    dcc.Graph(
        id='life-exp-vs-gdp',
        figure={
            'data': [
                go.Scatter(
                    x=df[df['continent'] == i]['gdp per capita'],
                    y=df[df['continent'] == i]['life expectancy'],
                    text=df[df['continent'] == i]['country'],
                    mode='markers',
                    opacity=0.7,
                    marker={
                        'size': 15,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    name=i
                ) for i in df.continent.unique()
            ],
            'layout': go.Layout(
                xaxis={'type': 'log', 'title': 'GDP Per Capita'},
                yaxis={'title': 'Life Expectancy'},
                margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
                legend={'x': 0, 'y': 1},
                hovermode='closest'
            )
        }
    )
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Running on http://127.0.0.1:8050/
# Running on http://127.0.0.1:8050/
# Running on http://127.0.0.1:8050/
# Running on http://127.0.0.1:8050/
# Running on http://127.0.0.1:8050/
# Debugger PIN: 445-326-062
# Debugger PIN: 445-326-062
# Debugger PIN: 445-326-062
# Debugger PIN: 445-326-062
# Debugger PIN: 445-326-062
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
import geopandasA

# %%
x = geopandas.read_file("./road_intersection_points.gpkg")

# %%
x.head()
# Out:
#         LINEARID   FULLNAME RTTYP  MTFCC     LINEARID_2      FULLNAME_2  \
# 0  1104259114336  I- 70 Bus     I  S1200  1104259508972       I- 70 Bus
# 1  1104259114336  I- 70 Bus     I  S1200  1104259508970       I- 70 Bus
# 2  1104259114336  I- 70 Bus     I  S1200  1104742588562       I- 70 Bus
# 3  1104259114336  I- 70 Bus     I  S1200  1104475295717       I- 70 Bus
# 4  1104259114336  I- 70 Bus     I  S1200   110765264627  N Speer Blvd W
#
#   RTTYP_2 MTFCC_2                               geometry
# 0       I   S1200  POINT (-104.986135 39.74006199999999)
# 1       I   S1200           POINT (-105.02986 39.740329)
# 2       I   S1200           POINT (-105.02986 39.740329)
# 3       I   S1200  POINT (-104.986135 39.74006199999999)
# 4       M   S1400           POINT (-104.99879 39.740022)

# %%
y = geopandas.read_file("./distancematrix.gpkg")

# %%
y.head()
# Out:
#         LINEARID   FULLNAME RTTYP  MTFCC     LINEARID_2      FULLNAME_2  \
# 0  1104259114336  I- 70 Bus     I  S1200  1104259508972       I- 70 Bus
# 1  1104259114336  I- 70 Bus     I  S1200  1104259508970       I- 70 Bus
# 2  1104259114336  I- 70 Bus     I  S1200  1104742588562       I- 70 Bus
# 3  1104259114336  I- 70 Bus     I  S1200  1104475295717       I- 70 Bus
# 4  1104259114336  I- 70 Bus     I  S1200   110765264627  N Speer Blvd W
#
#   RTTYP_2 MTFCC_2   type                   start  \
# 0       I   S1200  lines  -104.986135, 39.740062
# 1       I   S1200  lines   -105.02986, 39.740329
# 2       I   S1200  lines   -105.02986, 39.740329
# 3       I   S1200  lines  -104.986135, 39.740062
# 4       M   S1400  lines   -104.99879, 39.740022
#
#                                             geometry
# 0  (LINESTRING (-104.986135 39.74006199999999, -1...
# 1  (LINESTRING (-105.02986 39.740329, -105.02986 ...
# 2  (LINESTRING (-105.02986 39.740329, -105.02986 ...
# ...

# %%
X = raw_input().split(",")
print len(X),
for i in X:
    print i,
# Out:
# 273, 790, 131, 367, 914, 140, 727, 41, 628, 594, 725, 289, 205, 496, 290, 743, 363, 412, 644, 232, 173, 8, 787, 673, 798, 938, 510, 832, 495, 866, 628, 184, 654, 296, 734, 587, 142, 350, 870, 583, 825, 511, 184, 770, 173, 486, 41, 681, 82, 532, 570, 71, 934, 56, 524, 432, 307, 796, 622, 640, 705, 498, 109, 519, 616, 875, 895, 244, 688, 283, 49, 946, 313, 717, 819, 427, 845, 514, 809, 422, 233, 753, 176, 35, 76, 968, 836, 876, 551, 398, 12, 151, 910, 606, 932, 580, 795, 187
# 98 273  790  131  367  914  140  727  41  628  594  725  289  205  496  290  743  363  412  644  232  173  8  787  673  798  938  510  832  495  866  628  184  654  296  734  587  142  350  870  583  825  511  184  770  173  486  41  681  82  532  570  71  934  56  524  432  307  796  622  640  705  498  109  519  616  875  895  244  688  283  49  946  313  717  819  427  845  514  809  422  233  753  176  35  76  968  836  876  551  398  12  151  910  606  932  580  795  187

# %%
98 204  918  18  17  35  739  913  14  76  555  333  535  653  667  52  987  422  553  599  765  494  298  16  285  272  485  989  627  422  399  258  959  475  983  535  699  663  152  606  406  173  671  559  594  531  824  898  884  491  193  315  652  799  979  890  916  331  77  650  996  367  86  767  542  858  796  264  64  513  955  669  694  382  711  710  962  854  784  299  606  655  517  376  764  998  244  896  725  218  663  965  660  803  881  482  505  336  279
98 273  790  131  367  914  140  727  41  628  594  725  289  205  496  290  743  363  412  644  232  173  8  787  673  798  938  510  832  495  866  628  184  654  296  734  587  142  350  870  583  825  511  184  770  173  486  41  681  82  532  570  71  934  56  524  432  307  796  622  640  705  498  109  519  616  875  895  244  688  283  49  946  313  717  819  427  845  514  809  422  233  753  176  35  76  968  836  876  551  398  12  151  910  606  932  580  795  187

# %%
# !pip3 install geoalchemy2 sqlalchemy
# Out:
# ...
#     100% |████████████████████████████████| 5.9MB 62kB/s ta 0:00:012
# ...
#   Running setup.py bdist_wheel for sqlalchemy ... done
#   Stored in directory: /home/ashish/.cache/pip/wheels/f2/ec/e0/d7deb0c981557e373edf7370574b7001690892afe5fea30c3c
# Successfully built sqlalchemy
# ...

# %%
! conda install -c conda-forge geoalchemy2 sqlalchemy
# Out:
# ...
# Solving environment: /
# ...
#   - anaconda::ca-certificates-2019.1.23-0, anaconda::openssl-1.1.1b-h7b6447c_1
#   - anaconda::openssl-1.1.1b-h7b6447c_1, defaults::ca-certificates-2019.1.23-0
#   - anaconda::ca-certificates-2019.1.23-0, defaults::openssl-1.1.1b-h7b6447c_1
#   - defaults::ca-certificates-2019.1.23-0, defaults::openssl-1.1.1b-h7b6447cdone
#
# ## Package Plan ##
#
#   environment location: /home/ashish/anaconda3
#
#   added / updated specs:
#     - geoalchemy2
#     - sqlalchemy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.3.9           |           py37_0         149 KB  conda-forge
#     conda-4.7.10               |           py37_0         3.0 MB  conda-forge
#     geoalchemy2-0.6.3          |             py_0          20 KB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
# Imports
from geoalchemy2 import Geometry, WKTElement
from sqlalchemy import *
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd


# Creating SQLAlchemy's engine to use
engine = create_engine('postgresql://dtc:dtc@localhost:5432/dtcdb')


geodataframe = gpd.read_file('./Delhi/data/newjsdata/delhi_stops_csv.csv')
#... [do something with the geodataframe]

# geodataframe['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326)

#drop the geometry column as it is now duplicative
# geodataframe.drop(column=['geometry'])

# Use 'dtype' to specify column's type
# For the geom column, we will use GeoAlchemy's type 'Geometry'
# geodataframe.to_sql(table_name, engine, if_exists='append', index=False, 
#                          dtype={'geom': Geometry('POINT', srid= <your_srid>)})
# Out:
#   File "<ipython-input-54-ef1eed8ec507>", line 24
#     #                          dtype={'geom': Geometry('POINT', srid= <your_srid>)})
#                                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
# Out:
#   File "<ipython-input-21-f409f8b9e678>", line 9
#     geodataframe['geom'] = geodataframe['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326)
#                                                                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
# Imports
from geoalchemy2 import Geometry, WKTElement
from sqlalchemy import *
import pandas as pd
import geopandas as gpd
from sqlalchemy import *
from geoalchemy2 import Geometry


# Creating SQLAlchemy's engine to use
engine = create_engine('postgresql://dtc:dtc@localhost:5432/dtcdb')
cities = pd.read_csv('./Delhi/data/newjsdata/stops_lat_lon.csv')
geometry = [Point(xy) for xy in zip(cities['longitude'], cities['latitude'])]

# Coordinate reference system : WGS84
crs = {'init': 'epsg:4326'}

# Creating a Geographic data frame 
gdf = gpd.GeoDataFrame(cities, crs=crs, geometry=geometry)



#... [do something with the geodataframe]
# XX = pd.DataFrame.from_csv('./Delhi/data/newjsdata/delhi_stops_csv.csv')
# print(XX.keys())
# # XX = XX.drop(column=['geometry'])
# geodataframe = gpd.GeoDataFrame(XX)
# geodataframe['geom'] = geodataframe['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326)

#drop the geometry column as it is now duplicative
# geodataframe.drop(column=['geometry'])

# Use 'dtype' to specify column's type
# For the geom column, we will use GeoAlchemy's type 'Geometry'
# geodataframe.to_sql(table_name, engine, if_exists='append', index=False, 
#                          dtype={'geom': Geometry('POINT', srid= <your_srid>)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-fc9fdc9a803c> in <module>
#       9 engine = create_engine('postgresql://dtc:dtc@localhost:5432/dtcdb')
#      10 cities = pd.read_csv('./Delhi/data/newjsdata/stops_lat_lon.csv')
# ---> 11 geometry = [Point(xy) for xy in zip(cities['longitude'], cities['latitude'])]
#      12
#      13 # Coordinate reference system : WGS84
#
# <ipython-input-50-fc9fdc9a803c> in <listcomp>(.0)
#       9 engine = create_engine('postgresql://dtc:dtc@localhost:5432/dtcdb')
#      10 cities = pd.read_csv('./Delhi/data/newjsdata/stops_lat_lon.csv')
# ---> 11 geometry = [Point(xy) for xy in zip(cities['longitude'], cities['latitude'])]
#      12
#      13 # Coordinate reference system : WGS84
#
# NameError: name 'Point' is not defined

# %%
geodataframe.keys()
# Out:
# Index(['stop_id', 'stop_code', 'stop_name', 'latitude', 'longitude',
#        'geometry'],
#       dtype='object')

# %%
geodataframe.head()
# Out:
#   stop_id stop_code                       stop_name   latitude  longitude  \
# 0       0    U01761  Adarsh Nagar / Bharola Village  28.715917  77.170867
# 1       1    DC4248          British High Comission  28.598533  77.191383
# 2       2    U02398                     Azad Market    28.6647    77.2084
# 3       3    U02416                    Kidwai Nagar    28.5757    77.2097
# 4       4    DC4271                   Rashid Market    28.6502  77.278667
#
#   geometry
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None

# %%
from sqlalchemy import *
from geoalchemy2 import Geometry

engine = create_engine('postgresql://dtc:dtc@localhost:5432/dtcdb')

# create table
meta = MetaData(engine)
my_table = Table('stops_buses', meta)
# my_table.create(engine)

# DBAPI's executemany with list of dicts
# conn = engine.connect()
# conn.execute(my_table.insert(), df.to_dict('records'))

# %%
import geopandas as gpd

gdf = gpd.read_file('/home/ashish/repos/DTC-Project/Delhi/data/DTC_dataset/demo.csv')

# %%
gdf['geometry'] = [Point(xy) for xy in zip(map(float,gdf['longitude']), map(float,gdf['latitude']))]

# %%
gdf = gdf.drop(columns=['feed time','humantime'])

# %%
gdf
# Out:
#   vehicle_id trip_id route_id            latitude          longitude  \
# 0  DL1PD2659    1538       42    28.6978759765625  77.22063446044922
# 1  DL1PC5009    8573      329  28.527729034423828  77.28963470458984
# 2  DL1PC5494    8571      329  28.559871673583984  77.26777648925781
# 3  DL1PD1563   12894      447  28.642793655395508  77.31620788574219
# 4  DL1PD3272    3018      129   28.61137580871582  76.97660827636719
# 5  DL1PD1449   12893      447   28.64371681213379  77.31658935546875
# 6  DL1PD3550    3857      170   28.64840316772461  77.31742095947266
# 7  DL1PD2564   13759      469  28.661212921142578  77.23579406738281
# 8  DL1PD0041   11673      415  28.553163528442383  77.17985534667969
#
#                 speed   timestamp                                     geometry
# 0  0.2777777910232544  1559086113   POINT (77.22063446044922 28.6978759765625)
# 1   3.055555582046509  1559085994  POINT (77.28963470458984 28.52772903442383)
# ...

# %%
# conn = engine.connect()
# conn.execute(my_table.insert(), gdf.head(1).to_dict('records')[0])

# %%
gdf.head(1).to_dict('records')[0]
# Out:
# {'vehicle_id': 'DL1PD2659',
#  'trip_id': '1538',
#  'route_id': '42',
#  'latitude': '28.6978759765625',
#  'longitude': '77.22063446044922',
#  'speed': '0.2777777910232544',
#  'timestamp': '1559086113',
#  'geometry': <shapely.geometry.point.Point at 0x7fcbefc849b0>}

# %%
my_table.insert()

# %%
gdf['geom'] = gdf['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326)
# Out:
#   File "<ipython-input-82-fabedcff037b>", line 1
#     gdf['geom'] = gdf['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326)
#                                                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
import shapely.wkt

# %%
wkt = gdf['geometry'].ExportToWkt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-7e931ae1922a> in <module>
# ----> 1 wkt = gdf['geometry'].ExportToWkt()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'GeoSeries' object has no attribute 'ExportToWkt'

# %%
gdf
# Out:
#   vehicle_id trip_id route_id            latitude          longitude  \
# 0  DL1PD2659    1538       42    28.6978759765625  77.22063446044922
# 1  DL1PC5009    8573      329  28.527729034423828  77.28963470458984
# 2  DL1PC5494    8571      329  28.559871673583984  77.26777648925781
# 3  DL1PD1563   12894      447  28.642793655395508  77.31620788574219
# 4  DL1PD3272    3018      129   28.61137580871582  76.97660827636719
# 5  DL1PD1449   12893      447   28.64371681213379  77.31658935546875
# 6  DL1PD3550    3857      170   28.64840316772461  77.31742095947266
# 7  DL1PD2564   13759      469  28.661212921142578  77.23579406738281
# 8  DL1PD0041   11673      415  28.553163528442383  77.17985534667969
#
#                 speed   timestamp                                     geometry
# 0  0.2777777910232544  1559086113   POINT (77.22063446044922 28.6978759765625)
# 1   3.055555582046509  1559085994  POINT (77.28963470458984 28.52772903442383)
# ...

# %%
gdf.to_sql('stops_buses',engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-f2a1ad0062d9> in <module>
# ----> 1 gdf.to_sql('stops_buses',engine)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
import sql  # the patched version (file is named sql.py)
sql.w (gdf, 'stops_buses', con, flavor='postgresql')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-4391624a4c0f> in <module>
#       1 import sql  # the patched version (file is named sql.py)
# ----> 2 sql.write_frame(gdf, 'stops_buses', con, flavor='postgresql')
#
# AttributeError: module 'sql' has no attribute 'write_frame'

# %%
# !pip3 install sql

# %%
gdf.to_sql('stops_buses',engine,if_exists='append',method='multi')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     551     def do_execute(self, cursor, statement, parameters, context=None):
# --> 552         cursor.execute(statement, parameters)
#     553
#
# ProgrammingError: can't adapt type 'Point'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-94-a972bf07de01> in <module>
# ...

# %%
type(gdf['geometry'])
# Out:
# geopandas.geoseries.GeoSeries

# %%
gdf
# Out:
#   vehicle_id trip_id route_id            latitude          longitude  \
# 0  DL1PD2659    1538       42    28.6978759765625  77.22063446044922
# 1  DL1PC5009    8573      329  28.527729034423828  77.28963470458984
# 2  DL1PC5494    8571      329  28.559871673583984  77.26777648925781
# 3  DL1PD1563   12894      447  28.642793655395508  77.31620788574219
# 4  DL1PD3272    3018      129   28.61137580871582  76.97660827636719
# 5  DL1PD1449   12893      447   28.64371681213379  77.31658935546875
# 6  DL1PD3550    3857      170   28.64840316772461  77.31742095947266
# 7  DL1PD2564   13759      469  28.661212921142578  77.23579406738281
# 8  DL1PD0041   11673      415  28.553163528442383  77.17985534667969
#
#                 speed   timestamp                                     geometry
# 0  0.2777777910232544  1559086113   POINT (77.22063446044922 28.6978759765625)
# 1   3.055555582046509  1559085994  POINT (77.28963470458984 28.52772903442383)
# ...

# %%
df = pd.DataFrame(
    {'City': ['Buenos Aires', 'Brasilia', 'Santiago', 'Bogota', 'Caracas'],
     'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Venezuela'],
     'Coordinates': ['POINT(-34.58 -58.66)', 'POINT(-15.78 -47.91)',
                     'POINT(-33.45 -70.66)', 'POINT(4.60 -74.08)',
                     'POINT(10.48 -66.86)']})

# %%
from shapely import wkt

df['Coordinates'] = df['Coordinates'].apply(wkt.loads)
# The GeoDataFrame is constructed as follows :

gdf = gpd.GeoDataFrame(df, geometry='Coordinates')

print(gdf.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-b1a0b8ef31d4> in <module>
#       1 from shapely import wkt
#       2
# ----> 3 df['Coordinates'] = df['Coordinates'].apply(wkt.loads)
#       4 # The GeoDataFrame is constructed as follows :
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/anaconda3/lib/python3.7/site-packages/shapely/wkt.py in loads(data)
#       8 def loads(data):
#       9     """Load a geometry from a WKT string."""
# ...

# %%
wkt.loads(gpd['geometry'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-ca464a5e1bf8> in <module>
# ----> 1 wkt.loads(gpd['geometry'])
#
# TypeError: 'module' object is not subscriptable

# %%
# cur = connection.cursor()

# %%
gdf.keys()
# x = str(gdf.iloc[[0]]['vehicle_id'])
# Out:
# Index(['vehicle_id', 'trip_id', 'route_id', 'latitude', 'longitude', 'speed',
#        'timestamp', 'geometry'],
#       dtype='object')

# %%
print(len(x))
# Out:
# 46

# %%
print((gdf.iloc[[0]]['latitude'][0]))
# Out:
# 28.6978759765625

# %%
from psycopg2 import Error
try:
    connection = psycopg2.connect(host='localhost', dbname='dtcdb',   user='dtc', password='dtc')
    connection.autocommit=False
    sql = "INSERT INTO stops_buses (vehicle_id, trip_id, route_id, latitude, longitude, speed,timestamp, geometry) \
    VALUES (%s,%s,%s,%s,%s,%s,to_timestamp(%s,'yyyy-mm-dd hh24:mi:ss'), ST_SetSRID(ST_MakePoint(%s, %s), 4326))"
    with conn.cursor() as cur:
        cur.execute(sql, ((X['vehicle_id']),
                          (X['trip_id']),
                          (X['route_id']),
                          (X['latitude']),
                          (X['longitude']),
                          (X['speed']),
                          (str(datetime.datetime.fromtimestamp(int(X['timestamp'])))),
                          (X['longitude']),
                          (X['latitude']),                         
                         ))
    connection.commit()
    print("Transaction completed successfully ")
except (Exception, psycopg2.DatabaseError) as error :
    print ("Error in transction Reverting all other operations of a transction ", error)
    connection.rollback()
finally:
    #closing database connection.
    if(connection):
        connection.close()
        print("PostgreSQL connection is closed")

# %%
import psycopg2
from geoalchemy2 import Geometry, WKTElement
from sqlalchemy import *
import pandas as pd
import geopandas as gpd
from sqlalchemy import *
from geoalchemy2 import Geometry
def insert_to_buses(X):
    try:
        connection = psycopg2.connect(host='localhost', dbname='dtcdb',   user='dtc', password='dtc')
        connection.autocommit=False
        sql = "INSERT INTO stops_buses (vehicle_id, trip_id, route_id, latitude, longitude, speed,timestamp, geometry) \
        VALUES (%s,%s,%s,%s,%s,%s,to_timestamp(%s,'yyyy-mm-dd hh24:mi:ss'), ST_SetSRID(ST_MakePoint(%s, %s), 4326))"
        with connection.cursor() as cur:
            cur.execute(sql, ((X['vehicle_id']),
                              (X['trip_id']),
                              (X['route_id']),
                              (X['latitude']),
                              (X['longitude']),
                              (X['speed']),
                              (str(datetime.datetime.fromtimestamp(int(X['timestamp'])))),
                              (X['longitude']),
                              (X['latitude']),                         
                             ))
        connection.commit()
        print("Transaction completed successfully ")
    except (Exception, psycopg2.DatabaseError) as error :
        print ("Error in transction Reverting all other operations of a transction ", error)
        connection.rollback()
    finally:
        #closing database connection.
        if(connection):
            connection.close()
            print("PostgreSQL connection is closed")
def insert_to_stops(X):
    try:
        connection = psycopg2.connect(host='localhost', dbname='dtcdb',   user='dtc', password='dtc')
        connection.autocommit=False
        sql = "INSERT INTO stops_stops (stop_id, stop_name,stop_code,longitude, latitude, geometry) \
        VALUES (%s,%s,%s,%s,%s, ST_SetSRID(ST_MakePoint(%s, %s), 4326))"
        with connection.cursor() as cur:
            cur.execute(sql, ((X['stop_id']),
                              (X['stop_name']),
                              (X['stop_code']),
                              (X['longitude']),
                              (X['latitude']),
                              (X['longitude']),
                              (X['latitude']),                         
                             ))
        connection.commit()
        print("Transaction completed successfully ")
    except (Exception, psycopg2.DatabaseError) as error :
        print ("Error in transction Reverting all other operations of a transction ", error)
        connection.rollback()
    finally:
        #closing database connection.
        if(connection):
            connection.close()
            print("PostgreSQL connection is closed")

# %%
gdf = pd.read_csv('/home/ashish/repos/DTC-Project/Delhi/data/DTC_dataset/demo.csv')
stops_data = pd.read_csv('/home/ashish/repos/DTC-Project/Delhi/data/newjsdata/stops_lat_lon.csv')

# %%
len(gdf)
# Out:
# 9

# %%
insert_to_buses(gdf.T.to_dict()[7])
# Out:
# Transaction completed successfully
# PostgreSQL connection is closed

# %%
insert_to_stops(stops_data.T.to_dict()[7])
# Out:
# Transaction completed successfully
# PostgreSQL connection is closed

# %%
stops_dict = stops_data.T.to_dict()
for i in range(len(stops_data)):
    insert_to_stops(stops_dict[i])
# Out:
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# Transaction completed successfully
# PostgreSQL connection is closed
# ...

# %%
len(stops_data)
# Out:
# 3465

# %%
gdf.T.to_dict()[0]
# Out:
# {'vehicle_id': 'DL1PD2659',
#  'trip_id': '1538',
#  'route_id': '42',
#  'latitude': '28.6978759765625',
#  'longitude': '77.22063446044922',
#  'speed': '0.2777777910232544',
#  'timestamp': '1559086113',
#  'geometry': <shapely.geometry.point.Point at 0x7fcbefc849b0>}

# %%
import datetime

# %%
str(datetime.datetime.fromtimestamp(1559139806))
# Out:
# '2019-05-29 19:53:26'

# %%
datetime.datetime.timestamp((datetime.datetime.fromtimestamp(1559086113)))
# Out:
# 1559086113.0

# %%
import pandas as pd

# %%
routes_all = pd.read_csv("JS/leafletwebapp/static/buses_static_data/routes.txt")

# %%
df.head()
# Out:
#    route_short_name route_long_name  route_type  route_id
# 0               NaN         108DOWN           3         0
# 1               NaN      108STLDOWN           3         1
# 2               NaN        108STLUp           3         2
# 3               NaN           108UP           3         3
# 4               NaN         185DOWN           3         4

# %%
routes_all = {}

# %%
routes_all[0]
# Out:
# 0                            108DOWN
# 1                         108STLDOWN
# 2                           108STLUp
# 3                              108UP
# 4                            185DOWN
# 5                      185LnkSTLDown
# 6                        185LnkSTLUp
# 7                         185STLDOWN
# 8                           185STLUP
# 9                              185UP
# 10                        234CL_DOWN
# 11                          234CL_UP
# 12                           262DOWN
# 13                    262LinkSTLDown
# 14                      262LinkSTLUP
# 15                             262UP
# 16                            78DOWN
# 17                         78STLDOWN
# 18                           78STLUP
# 19                              78UP
# 20                       7LnkSTLDown
# 21                         7LnkSTLUp
# 22                         813CLDown
# 23                           813CLUP
# 24                     813LnkSTLDown
# ...
